# %% [markdown]
# # Intro to Data Visualization using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
arr=np.random.randint(0,100,200)
arr
# Out:
# array([40, 73, 41, 93, 87, 78, 61, 33,  9, 22, 96, 54, 33, 94, 25, 29, 39,
#        65, 16, 61, 48, 88, 10, 76, 49, 62, 93,  9, 65, 55, 62, 39, 24, 85,
#        78, 70, 56, 64, 61, 44, 17, 58, 52, 77, 53, 50, 12, 71, 29, 33, 70,
#        71, 94, 68, 74, 14, 70, 85, 45, 64, 12, 49, 74, 37, 10, 67, 47, 27,
#        95, 43, 90, 56, 75, 89, 65, 82, 20, 67, 19, 88, 55, 56, 79,  2, 93,
#        73, 89, 43, 82, 37, 55, 62, 57, 67, 40, 28, 69, 36, 26, 91, 77, 50,
#        65, 91, 79, 19, 31, 24, 85, 81, 99, 61, 69, 72, 69, 83, 98,  3,  9,
#        77, 99, 78, 71, 91, 20, 70, 84, 65, 80, 41, 93, 54, 34, 61, 44, 67,
#        15, 62, 19, 27, 71, 15, 26, 76, 71,  7,  5, 85, 54,  3, 62, 69, 15,
#        56, 57, 14, 31, 89, 73,  6, 28, 53, 74, 62, 39, 93, 34, 34, 86, 79,
#        34,  4, 56,  7, 94, 41, 52, 58, 17,  3, 51, 35, 96, 15, 62, 76, 60,
#        93, 78, 57, 45, 70, 21, 11, 87, 82, 66, 83, 19, 94])

# %%
arr2=np.random.randint(0,100,200)
arr2
# Out:
# array([79, 21, 56, 41,  0, 79, 49, 10,  8, 60, 21, 30, 68, 10, 40, 25, 90,
#        26, 44, 47, 51,  0, 21,  1, 68, 19, 75, 23,  3, 51, 86, 59, 37, 17,
#        47, 39, 98, 50, 87, 18, 68, 37,  4, 12, 64, 30, 53, 29, 53,  3, 69,
#        36, 45, 65, 22, 83, 52, 38, 39, 79, 38, 55, 28, 60, 37, 50, 23, 86,
#        22, 96, 81, 59, 65, 76, 15, 82, 47, 47, 17, 55, 87, 20, 96, 46, 21,
#        98, 63, 96,  4, 41, 10, 50, 32, 60, 67, 94, 77, 90, 99, 41, 59, 35,
#        85, 31,  1, 44, 90, 18, 16, 34, 44,  3, 25, 34, 32, 29, 72, 58, 82,
#         7, 86, 79, 77, 73, 63,  6,  6, 89, 44,  6, 16, 47, 34, 17, 59, 99,
#        39, 27, 43, 25, 29, 13,  9,  3,  6, 70, 10, 91, 96, 57, 45, 90, 21,
#        36, 93, 28, 57, 86,  8, 33, 59, 36, 27, 67, 64,  2,  6, 83, 80, 29,
#        83, 73, 65, 49, 31, 97, 15, 55, 95, 13, 38, 31, 85, 25, 21, 65, 32,
#        39, 13, 58, 89, 94, 77, 57, 63, 59, 61, 48,  9, 35])

# %%
# plt.plot(arr)
plt.figure(figsize=(15,8))
plt.scatter(np.arange(0,200), arr, s=12, c="red", marker="D", label="Male")
plt.scatter(np.arange(0,200), arr2, s=12, c="green", marker="*", label="Female")
plt.legend()
plt.xlabel("Number of people")
plt.ylabel("Age")
plt.title("Number of people vs Age")
# Out:
# Text(0.5, 1.0, 'Number of people vs Age')

# %%
arr=[2,3,4,6,1,5]
plt.plot(arr, marker="*", mec="red", mfc="black")

# %%
plt.figure(figsize=(10,8))
plt.plot(arr, marker="*", mec="red", mfc="black")

# %%
plt.plot(arr, "*", mec="red", mfc="black")

# %%
arr=np.random.randint(0,100,50)
arr
# Out:
# array([97, 34, 72, 89, 83, 27,  3,  3, 28, 81, 21, 80, 36, 61, 91, 55, 92,
#        97, 41, 81, 64, 56, 42, 65, 47, 18, 14, 80, 51, 62, 38, 33,  3, 81,
#        16, 58,  7,  4, 92, 54, 81, 28, 92, 39, 15, 52, 70, 59, 45, 35])

# %%
plt.figure(figsize=(12,5))
plt.bar(np.arange(50),arr, width=0.8)
# Out:
# <BarContainer object of 50 artists>

# %%
# plt.barh(np.arange(50),arr, width=0.8)
# plt.barh(np.arange(50),arr, width=0.8)
plt.barh(np.arange(50), arr )
# Out:
# <BarContainer object of 50 artists>

# %%
arr=np.random.randint(0,100,500)
arr
# Out:
# array([72,  9, 33, 18, 10, 99, 52,  0, 25, 83, 99, 23, 98, 41, 31, 49, 29,
#        22, 99,  0, 26, 11, 68, 75, 29, 40, 14, 52, 49, 57, 56, 54, 57, 80,
#        64,  7, 21,  7, 55,  8, 73, 30, 72, 56, 31, 97, 21, 51, 39,  0, 19,
#        45, 79, 39, 89, 30, 24, 45, 85, 93, 95, 21, 59, 32, 48, 64, 78, 34,
#        27, 12, 64, 52, 86, 48, 17, 15, 42, 92, 78,  6, 41, 62, 32, 42, 36,
#        75, 77, 87,  7, 63, 31, 15, 92, 29, 13, 22, 99, 96, 56,  0, 58, 75,
#        26, 73, 32, 21, 87, 45, 58, 50, 94, 74, 23,  6, 57,  0, 10, 31, 85,
#        21, 10, 18, 11, 59, 74, 27, 19, 78, 68, 24, 97, 63, 56, 20,  4, 55,
#        29, 81, 72,  6, 62, 32, 50, 48, 99, 26, 36, 39, 56, 35, 66, 99, 92,
#        49, 57, 27, 67, 70, 80, 62, 62, 44, 79, 62, 84, 89,  8, 20, 85, 98,
#        95, 31,  5, 84, 51, 88, 26, 77, 65, 41, 51, 42, 64, 21, 73, 41, 56,
#         0, 91, 31, 43, 70, 73, 15, 27, 84, 17, 82, 33,  4, 34,  6, 83, 78,
# ...

# %%
plt.hist(arr,bins=10, color="red")
# Out:
# (array([42., 51., 65., 57., 48., 48., 44., 43., 56., 46.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
arr=np.array([1,5,6,2,7])
plt.pie(arr, 
        # labels=arr.astype("str")
        labels=["Car", "van", "Jeep", "bike", "bus"],
        explode=[0,0.1,0,0,0],
        colors=["red", "blue", "yellow", "green", "black"]
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x724a0e5daf50>,
# ...
#  [Text(1.0877139078161349, 0.1639464996373907, 'Car'),
#   Text(0.5999999697158604, 1.039230502025882, 'van'),
#   Text(-0.9910659367585292, 0.47727173496545894, 'Jeep'),
#   Text(-0.8063568251311835, -0.7481902636123771, 'bike'),
#   Text(0.5500003659264657, -0.9526277328950455, 'bus')])
