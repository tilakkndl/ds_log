# %% [markdown]
# # Intro to Data Visualization using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
arr=np.random.randint(0,100,200)
arr
# Out:
# array([24, 72, 99, 50, 26, 53, 33, 16, 11, 58, 24, 89, 99, 36, 56, 27, 91,
#        40, 64, 65, 70, 63, 28, 38, 10, 43, 52, 68, 58, 36, 33, 58, 19, 90,
#        36, 34, 94, 54, 15, 93, 53, 84, 72, 16, 87, 48, 37, 80, 20, 31, 34,
#        31, 40, 82, 54, 54,  4, 88, 93, 35, 50, 92, 14,  0, 65, 66, 86, 26,
#        99,  6,  5, 74, 53, 56, 17, 70, 27,  5, 89, 70, 93, 24, 30, 73, 75,
#        24,  9,  1, 22, 23, 85, 47, 37, 38, 58, 99, 57, 85, 83, 79, 24, 54,
#        70, 10, 59, 22, 29, 45, 29, 51, 44, 76, 15,  3,  2, 50, 63, 73, 61,
#        84, 77, 24, 44, 79, 91, 66, 82, 96,  7,  4, 70, 80, 79, 86, 46, 71,
#        47, 66, 22, 15, 45, 12, 17, 94, 28, 26, 73, 86, 71, 72, 18, 49,  2,
#        43, 86, 54, 41, 18, 40, 31,  4, 64, 54, 54, 59,  3, 31, 62, 18, 63,
#        36, 34, 55, 34, 63, 34, 38, 28, 58, 17, 49, 20, 13,  3, 20, 29, 22,
#        59, 74, 47, 76,  0, 89, 14, 10, 72,  5, 24, 56,  7])

# %%
arr2=np.random.randint(0,100,200)
arr2
# Out:
# array([94, 89, 75, 82, 65, 92, 44, 23,  6, 29, 12, 10, 82,  6, 28, 83, 68,
#        33, 37, 47, 45, 74, 65, 54, 12, 19,  9, 14, 79, 38, 24, 50, 65, 81,
#        19, 20, 65, 15, 31, 66, 46, 56, 40, 58, 42, 58, 83, 22, 53, 63, 82,
#        48, 30,  8, 44, 73, 93, 52, 84, 39, 66, 10, 82, 91, 22, 69,  2,  9,
#        32, 94, 50, 91, 87, 56, 83, 18, 11,  7, 14, 54, 36, 39, 98, 76,  9,
#        40,  5, 40, 94, 63, 21, 35, 29, 43,  0, 55, 98, 48, 79, 94, 73, 56,
#        29,  7, 13, 37, 60, 52, 20, 98, 33, 57, 47,  4,  6, 54, 46, 75, 90,
#        29, 83, 72, 62, 23, 60, 91, 84, 64, 30, 40, 16, 94, 66, 63, 46,  3,
#        54,  7, 74,  0, 28, 51, 87, 31, 96, 57, 81, 42, 26, 84, 81, 25, 44,
#        87, 42, 40, 10, 30, 63, 51, 64, 13, 36, 67, 96, 68, 89, 50, 23, 12,
#        48, 11, 45, 33, 74, 64, 77, 65, 34, 40, 93, 78, 92,  0, 11,  3, 82,
#        98, 84, 86, 37, 77, 22, 92,  9, 75, 14, 83, 39, 92])

# %%
# plt.plot(arr)
plt.figure(figsize=(15,8))
plt.scatter(np.arange(0,200), arr, s=12, c="red", marker="D", label="Male")
plt.scatter(np.arange(0,200), arr2, s=12, c="green", marker="*", label="Female")
plt.legend()
plt.xlabel("Number of people")
plt.ylabel("Age")
plt.title("Number of people vs Age")
# Out:
# Text(0.5, 1.0, 'Number of people vs Age')

# %%
arr=[2,3,4,6,1,5]
plt.plot(arr, marker="*", mec="red", mfc="black")

# %%
plt.figure(figsize=(10,8))
plt.plot(arr, marker="*", mec="red", mfc="black")

# %%
plt.plot(arr, "*", mec="red", mfc="black")

# %%
arr=np.random.randint(0,100,50)
arr
# Out:
# array([12, 31, 12, 91, 14, 96,  4, 39, 13, 18, 97, 94, 74, 41,  6, 94, 95,
#        32, 45, 30, 84, 18,  4, 67, 30, 10, 58, 95, 42, 72, 88, 34, 25, 35,
#        72,  2,  8,  0, 73, 22, 11,  5, 24, 41, 55, 31, 58, 94, 64, 81])

# %%
plt.figure(figsize=(12,5))
plt.bar(np.arange(50),arr, width=0.8)
# Out:
# <BarContainer object of 50 artists>

# %%
# plt.barh(np.arange(50),arr, width=0.8)
# plt.barh(np.arange(50),arr, width=0.8)
plt.barh(np.arange(50), arr )
# Out:
# <BarContainer object of 50 artists>

# %%
arr=np.random.randint(0,100,500)
arr
# Out:
# array([64,  5, 62,  4, 15,  4, 42, 24, 77, 16, 62, 34, 53, 96, 45,  2, 36,
#        21, 79, 63, 73, 15, 93, 71,  6, 74, 22, 43, 10, 61, 11, 45,  1, 95,
#        84, 57, 89, 57, 57, 68, 93, 64, 40, 88, 58, 17, 40, 25, 85, 39, 91,
#        86, 58, 90, 29,  0, 99, 69, 92, 44, 33, 65, 64, 51, 53, 95, 58, 19,
#         8, 24, 15, 77, 71, 32, 52, 19, 64, 78, 84, 27, 51, 32, 17, 51, 59,
#        37, 65, 14,  6, 52, 88, 53,  7, 23,  9, 56, 94, 58, 73, 60, 64, 62,
#        25, 46, 77, 91, 38, 13, 82, 83, 67, 44, 53, 19, 15, 99,  6, 69,  1,
#        15, 24, 72, 25, 18, 84,  9, 47, 96, 61, 62, 43, 16, 73, 66, 69, 39,
#        14, 14, 36, 86, 17, 75, 47,  5,  0, 14, 66, 43, 18, 22, 43, 82, 45,
#         1, 88, 31, 30, 48, 68, 96, 32, 47,  3, 53, 40, 67, 81, 10,  9, 41,
#        32, 76, 26, 86,  6, 59, 57, 31, 23, 27, 31, 70, 94,  9, 16, 51, 62,
#        86, 87, 60, 81, 47, 96, 65,  8, 57, 72, 52, 14,  8, 90, 56, 94, 33,
#        66, 77, 46, 65,  6, 18,  2,  9, 58,  2, 16, 39, 30, 33, 40, 58, 36,
#        14, 32, 97, 36, 86, 81, 90, 10, 18, 49, 82, 37, 23, 32, 24, 85, 86,
#        63, 45, 30, 94, 47, 90,  5, 82,  3, 41, 96, 40, 26, 30, 15, 66, 81,
#        24, 35,  1, 65, 38, 51, 73, 58, 85, 63, 21, 16,  0,  5, 63, 16,  4,
#        92,  1, 95, 17, 26,  2, 87, 12, 92,  9, 33, 91, 22, 58, 82,  6, 35,
#        43, 91, 79, 55, 51, 23, 64,  6, 43,  1, 31, 98, 84, 26, 38, 99, 35,
#        26, 43, 82, 37, 95, 28, 97, 50,  9, 29,  5, 26, 85, 99, 37, 74, 23,
#        55, 65,  6, 73,  6, 65, 70, 17, 18, 55, 17, 38, 42, 31, 78, 58, 35,
#         7, 97, 74, 35, 71, 66, 67, 31,  2, 66, 46, 34, 56, 37, 62, 79, 74,
#        36, 52, 95, 59, 71, 64, 96, 85, 48, 67, 47, 29, 71, 23, 88, 99, 67,
#        19, 60, 89, 71, 50, 11, 87, 11, 84, 20, 57, 71, 92, 16, 41, 93, 29,
#        94, 80, 24, 85, 68, 37, 27, 84, 17, 38, 84, 60, 33, 68, 66, 94, 76,
#         2,  5, 77, 46, 49, 58, 45, 64, 42, 78, 24, 66, 17, 99, 83,  4, 66,
#        34, 46, 11,  3,  8, 50, 49, 48, 99, 62,  4, 42, 86, 36, 89, 75,  8,
#        61, 60, 53, 63, 97,  7, 45, 38, 65, 69, 78, 95, 50, 50, 94, 18, 80,
#        30, 26, 19, 90, 95, 13, 95, 28, 26, 85, 62, 28, 45, 10, 28, 29, 30,
#        22, 73, 49, 67, 49, 33, 59,  0, 36, 27, 75,  8, 81, 34, 59, 55, 88,
#        12, 77,  6, 34, 18, 93, 28])

# %%
plt.hist(arr,bins=10, color="red")
# Out:
# (array([7., 8., 3., 7., 5., 3., 2., 4., 2., 9.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
arr=np.array([1,5,6,2,7])
plt.pie(arr, 
        # labels=arr.astype("str")
        labels=["Car", "van", "Jeep", "bike", "bus"],
        explode=[0,0.1,0,0,0],
        colors=["red", "blue", "yellow", "green", "black"]
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x750251a9d310>,
#   <matplotlib.patches.Wedge at 0x750251a9ea50>,
#   <matplotlib.patches.Wedge at 0x750251ab8090>,
#   <matplotlib.patches.Wedge at 0x750251ab9290>,
#   <matplotlib.patches.Wedge at 0x750251aba450>],
#  [Text(1.0877139078161349, 0.1639464996373907, 'Car'),
#   Text(0.5999999697158604, 1.039230502025882, 'van'),
#   Text(-0.9910659367585292, 0.47727173496545894, 'Jeep'),
#   Text(-0.8063568251311835, -0.7481902636123771, 'bike'),
#   Text(0.5500003659264657, -0.9526277328950455, 'bus')])
